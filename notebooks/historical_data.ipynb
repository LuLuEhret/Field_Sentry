# %%
from insolAPI.WebAPI import API
import simplejson as json
import pandas as pd
import pendulum as pdl
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from datetime import datetime, timedelta
import warnings
from tqdm import tqdm
import sys
import pytz

# %%
time_args = dict(
    start=pdl.yesterday().subtract(months=1).to_datetime_string(),
    stop=(pdl.yesterday().add(days=1)).to_datetime_string(),
    timezone="UTC",
)

def read_json_config():
    """
    Read the config.json file and return the api key
    """
    with open("config.json") as f:
        config_data = json.load(f)

    installations = {}

    # Iterate through locations
    locations = config_data['locations']
    for location in locations:
        # Store details in a dictionary
        location_details = {
            'id': location['id'],
            'name': location['name'],
            'latitude': location['latitude'],
            'longitude': location['longitude'],
            'wind_threshold': location['wind_threshold'],
            'high_temperature_threshold': location['high_temperature_threshold'],
            'has_a_screen': location['has_a_screen'],
        }
        installations[location['name']] = location_details
    return installations, [config_data['api_key'], config_data['api_url']]


installation_path = "C:/Users/Insolight/Desktop/InsolReports/Scripts"
with open(installation_path + "/local.json") as f:
    local_data = json.load(f)
api = API(local_data["API_user"], local_data["API_pwd"], dev_space=False)

list_sensor = [
    "PAR",
    "IRRAD",
    "GII",
    "DNI",
    "DHI",
    "TEMP",
    "HUMI",
    "RAIN",
    "RAIN_TYPE",
    "RAIN_ACCUMULATED",
    "WIND",
    "WIND_DIR",
    "VIRTUAL",
    "LEAF_TEMP"
]

dict_instal = {
    "Etchelecu": 26,
    "Agroscope Series": 24,
    "Agroscope Berries": 25,
    "Bioschmid": 23,
}

# %%
sensor_number = 0
logs_joined = {}
dict_merged_df = {}
dict_df_missing_values = {}
df_log_unique_sensor = {}
print("Date range: " + time_args['start'] + " to " + time_args['stop'])
for instal in dict_instal:
    print(instal)
    sensor_number = 0
    logs_joined[instal] = {}
    dict_merged_df[instal] = {}
    dict_df_missing_values[instal] = {}
    df_log_unique_sensor[instal] = {}
    for sensor_type in tqdm(api.SensorsTypes):
        if str(sensor_type).split(".")[1] in list_sensor:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore", category=UserWarning)
                logs_joined[instal][list_sensor[sensor_number]] = api.get_sensor_channels_logs_joined(**time_args,sensor_type=sensor_type, install=dict_instal[instal])
                sensor_number += 1

    for sensor in list_sensor:
        if logs_joined[instal][sensor].empty:
            continue
        list_unique_sensors = logs_joined[instal][sensor]['sensor_name'].unique()
        for unique_sensor in list_unique_sensors:
            df_log_unique_sensor[instal][unique_sensor] = logs_joined[instal][sensor].loc[logs_joined[instal][sensor]['sensor_name']==unique_sensor].copy()
            df_log_unique_sensor[instal][unique_sensor].reset_index(inplace=True)
            df_log_unique_sensor[instal][unique_sensor].rename(columns={'index':'time'}, inplace=True)
            df_log_unique_sensor[instal][unique_sensor]['time'] = pd.to_datetime(df_log_unique_sensor[instal][unique_sensor]['time'])
            df_log_unique_sensor[instal][unique_sensor]['time'] = df_log_unique_sensor[instal][unique_sensor]['time'].dt.round('10min')
            df_log_unique_sensor[instal][unique_sensor].drop_duplicates(subset=['time','sensor_name'], inplace=True)
            #need to use the now end
            # date_range = pd.date_range(start=df_log_unique_sensor[instal][unique_sensor]['time'].min(), end=df_log_unique_sensor[instal][unique_sensor]['time'].max() + pd.DateOffset(0), freq='10min')
            date_range = pd.date_range(start=df_log_unique_sensor[instal][unique_sensor]['time'].min().tz_localize(None), end=pd.to_datetime(datetime.now().strftime("%Y-%m-%d %H:%M:%S")) + pd.DateOffset(0), freq='10min')
            date_range = date_range.tz_localize(pytz.timezone('UTC'))
            full_df = pd.DataFrame(date_range, columns=['time'])
            dict_merged_df[instal][unique_sensor] = pd.merge(full_df, df_log_unique_sensor[instal][unique_sensor], how='left', on="time")
            columns = dict_merged_df[instal][unique_sensor].columns
            dict_merged_df[instal][unique_sensor].rename(columns={columns[2]:'value_sensor'}, inplace=True)

            #counting missing values
            old_day = 0
            missing_values = 0
            dict_days = {}
            for index, row in dict_merged_df[instal][unique_sensor].iterrows():
                new_day = row['time'].day
                if new_day == old_day and pd.isnull(row["value_sensor"]):
                    missing_values += 1
                if new_day != old_day:
                    dict_days[datetime(year=row["time"].year, month=row["time"].month, day=row["time"].day) - timedelta(days=1)] = missing_values*10 / 1430 * 100
                    old_day = new_day
                    missing_values = 0
            dict_df_missing_values[instal][unique_sensor] = pd.DataFrame.from_dict(dict_days, orient='index')

    fig = go.Figure()
    for i in dict_df_missing_values[instal]:
        fig.add_trace(go.Scatter(x=dict_df_missing_values[instal][i].index, y=dict_df_missing_values[instal][i][0], name=i))
        fig.update_layout(yaxis_title='% of day disconnected', hovermode='x', title=instal, hoverlabel=dict(bgcolor="white"))
        #add a title

    fig.show()
    #save figure as html in a folder named "results"
    fig.write_html("../missing_sensors_recap/" + instal + '.html')
# Out:
# Date range: 2023-12-02 00:00:00 to 2024-01-03 00:00:00
# Etchelecu
#  20%|██        | 5/25 [00:05<00:21,  1.08s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 18
#      16         with warnings.catch_warnings():
#      17             warnings.simplefilter("ignore", category=UserWarning)
# ---> 18             logs_joined[instal][list_sensor[sensor_number]] = api.get_sensor_channels_logs_joined(**time_args,sensor_type=sensor_type, install=dict_instal[instal])
#      19             sensor_number += 1
#      21 for sensor in list_sensor:
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\insolAPI\WebAPI.py:616, in API.get_sensor_channels_logs_joined(self, *args, **kwargs)
#     615 def get_sensor_channels_logs_joined(self, *args, **kwargs):
# --> 616     logs = self.get_sensor_channels_logs_csv(*args, **kwargs)
#     617     specs = self.get_sensor_channels(*args, **kwargs)
#     618     return logs.join(specs, on="sensor_channel_id")
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\insolAPI\WebAPI.py:598, in API.get_sensor_channels_logs_csv(self, start, sensor_type, position_contains, **kwargs)
#     595 if position_contains:
#     596     settings["position_contains"] = [pos.value for pos in position_contains]
# --> 598 data = self.act("get", f"installation/{i}/sensor_channels/export", json=settings)["text"]
#     599 return parse_csv(data, time_col="Time (UTC)", tz_src="UTC", tz_dst=timezone, dayfirst=False, separator="\t")
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\insolAPI\WebAPI.py:266, in API.act(self, act_type, path, refresh, **kwargs)
#     264 tstart = time.time()
#     265 logger.info(f"{act_type.upper()} {path}")
# --> 266 resp: requests.Response = getattr(self._s, act_type)(f"{self.base_address}api/{path}", **kwargs)
#     267 logger.info(f"request duration: {time.time() - tstart}")  # Manually as there can be
#     269 if resp.status_code == requests.codes["unauthorized"] and not refresh and hasattr(self, "_tokens"):
#     270     # Try refreshing (only once)
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\requests\sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\urllib3\response.py:831, in HTTPResponse.read_chunked(self, amt, decode_content)
#     829 if self.chunk_left == 0:
#     830     break
# --> 831 chunk = self._handle_chunk(amt)
#     832 decoded = self._decode(
#     833     chunk, decode_content=decode_content, flush_decoder=False
#     834 )
#     835 if decoded:
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\urllib3\response.py:784, in HTTPResponse._handle_chunk(self, amt)
#     782     returned_chunk = value
#     783 else:  # amt > self.chunk_left
# --> 784     returned_chunk = self._fp._safe_read(self.chunk_left)
#     785     self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     786     self.chunk_left = None
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\http\client.py:631, in HTTPResponse._safe_read(self, amt)
#     624 def _safe_read(self, amt):
#     625     """Read the number of bytes requested.
#     626
#     627     This function should be used when <amt> bytes "should" be present for
#     628     reading. If the bytes are truly not available (due to EOF), then the
#     629     IncompleteRead exception can be used to detect the problem.
#     630     """
# --> 631     data = self.fp.read(amt)
#     632     if len(data) < amt:
#     633         raise IncompleteRead(data, amt-len(data))
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # End of notebook

# %%
dict_df_per_day = {}
for instal in dict_instal:
    dict_df_per_day[instal] = pd.DataFrame()
    for i in dict_df_missing_values[instal]:
        # print(i)
        dict_df_per_day[instal][i] = dict_df_missing_values[instal][i][0]

# %%
dict_merged_df["Bioschmid"]["WIND02_EXT"]
# Out:
#                           time  sensor_channel_id  value_sensor
# 0    2023-11-19 00:00:00+00:00             1084.0         157.0  \
# 1    2023-11-19 00:10:00+00:00             1084.0          49.0
# 2    2023-11-19 00:20:00+00:00             1084.0         202.0
# 3    2023-11-19 00:30:00+00:00             1084.0         157.0
# 4    2023-11-19 00:40:00+00:00             1084.0         133.0
# ...                        ...                ...           ...
# 4315 2023-12-18 23:10:00+00:00                NaN           NaN
# 4316 2023-12-18 23:20:00+00:00                NaN           NaN
# 4317 2023-12-18 23:30:00+00:00                NaN           NaN
# 4318 2023-12-18 23:40:00+00:00                NaN           NaN
# 4319 2023-12-18 23:50:00+00:00             1084.0         122.0
#
#       integrated [° · h]  gateway_id  local_channel_id
# 0             135.427078        28.0              86.0  \
# 1             144.810410        28.0              86.0
# 2             165.827087        28.0              86.0
# 3             194.202087        28.0              86.0
# 4             219.552078        28.0              86.0
# ...                  ...         ...               ...
# 4315                 NaN         NaN               NaN
# 4316                 NaN         NaN               NaN
# 4317                 NaN         NaN               NaN
# 4318                 NaN         NaN               NaN
# 4319          100.780418        28.0              86.0
#
#                        created_at deleted_at sensor_name    channel_name  ...
# 0     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...  \
# 1     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...
# 2     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...
# 3     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...
# 4     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...
# ...                           ...        ...         ...             ...  ...
# 4315                          NaN        NaN         NaN             NaN  ...
# 4316                          NaN        NaN         NaN             NaN  ...
# 4317                          NaN        NaN         NaN             NaN  ...
# 4318                          NaN        NaN         NaN             NaN  ...
# 4319  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  ...
#
#       serial_number  configuration_json address   dx   dy   dz   nx   ny
# 0         R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0  \
# 1         R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0
# 2         R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0
# 3         R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0
# 4         R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0
# ...             ...                 ...     ...  ...  ...  ...  ...  ...
# 4315            NaN                 NaN     NaN  NaN  NaN  NaN  NaN  NaN
# 4316            NaN                 NaN     NaN  NaN  NaN  NaN  NaN  NaN
# 4317            NaN                 NaN     NaN  NaN  NaN  NaN  NaN  NaN
# 4318            NaN                 NaN     NaN  NaN  NaN  NaN  NaN  NaN
# 4319      R23031310                  []    86.0  0.0  0.0  0.0  1.0  1.0
#
#             zones_ids                                        zones_names
# 0     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 1     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 3     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 4     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# ...               ...                                                ...
# 4315              NaN                                                NaN
# 4316              NaN                                                NaN
# 4317              NaN                                                NaN
# 4318              NaN                                                NaN
# 4319  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
#
# [4320 rows x 24 columns]

# %%
df_log_unique_sensor["Bioschmid"]["WIND02_EXT"]
# Out:
#                            time  sensor_channel_id  Wind direction [°]
# 0     2023-11-19 00:00:00+00:00               1084                 157  \
# 5     2023-11-19 00:10:00+00:00               1084                  49
# 12    2023-11-19 00:20:00+00:00               1084                 202
# 19    2023-11-19 00:30:00+00:00               1084                 157
# 25    2023-11-19 00:40:00+00:00               1084                 133
# ...                         ...                ...                 ...
# 21013 2023-12-18 22:30:00+00:00               1084                 163
# 21015 2023-12-18 22:40:00+00:00               1084                 203
# 21016 2023-12-18 22:50:00+00:00               1084                 127
# 21018 2023-12-18 23:00:00+00:00               1084                 104
# 21020 2023-12-18 23:50:00+00:00               1084                 122
#
#        integrated [° · h]  gateway_id  local_channel_id
# 0              135.427078          28                86  \
# 5              144.810410          28                86
# 12             165.827087          28                86
# 19             194.202087          28                86
# 25             219.552078          28                86
# ...                   ...         ...               ...
# 21013         3633.378418          28                86
# 21015         3639.331055          28                86
# 21016         3669.581055          28                86
# 21018            0.388333          28                86
# 21020          100.780418          28                86
#
#                         created_at deleted_at sensor_name    channel_name
# 0      2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  \
# 5      2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 12     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 19     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 25     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# ...                            ...        ...         ...             ...
# 21013  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21015  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21016  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21018  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21020  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
#
#        ...  serial_number  configuration_json address dx dy dz  nx  ny
# 0      ...      R23031310                  []      86  0  0  0   1   1  \
# 5      ...      R23031310                  []      86  0  0  0   1   1
# 12     ...      R23031310                  []      86  0  0  0   1   1
# 19     ...      R23031310                  []      86  0  0  0   1   1
# 25     ...      R23031310                  []      86  0  0  0   1   1
# ...    ...            ...                 ...     ... .. .. ..  ..  ..
# 21013  ...      R23031310                  []      86  0  0  0   1   1
# 21015  ...      R23031310                  []      86  0  0  0   1   1
# 21016  ...      R23031310                  []      86  0  0  0   1   1
# 21018  ...      R23031310                  []      86  0  0  0   1   1
# 21020  ...      R23031310                  []      86  0  0  0   1   1
#
#              zones_ids                                        zones_names
# 0      [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 5      [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 12     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 19     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 25     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# ...                ...                                                ...
# 21013  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21015  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21016  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21018  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21020  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
#
# [3793 rows x 24 columns]

# %% [markdown]
# # test

# %%
test = api.get_sensor_channels_logs_joined(**time_args,sensor_type=api.SensorsTypes.WIND, install=23)
# Out:
# c:\Users\Insolight\mambaforge\envs\insolinsights\Lib\site-packages\insolAPI\WebAPI.py:76: UserWarning:
#
# The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.

# %%
test
# Out:
#                            sensor_channel_id  Wind speed [m/s]
# 2023-11-19 00:00:44+00:00               1083              0.80  \
# 2023-11-19 00:00:45+00:00               1085              1.11
# 2023-11-19 00:01:44+00:00               1083              0.70
# 2023-11-19 00:01:45+00:00               1085              0.90
# 2023-11-19 00:02:44+00:00               1083              0.10
# ...                                      ...               ...
# 2023-12-18 23:55:12+00:00               1083              0.60
# 2023-12-18 23:56:11+00:00               1083              1.00
# 2023-12-18 23:57:11+00:00               1083              0.60
# 2023-12-18 23:58:11+00:00               1083              1.00
# 2023-12-18 23:59:11+00:00               1083              0.60
#
#                            integrated [m/s · h]  gateway_id  local_channel_id
# 2023-11-19 00:00:44+00:00              0.760278          28                85  \
# 2023-11-19 00:00:45+00:00              1.164896          28                87
# 2023-11-19 00:01:44+00:00              0.772778          28                85
# 2023-11-19 00:01:45+00:00              1.181646          28                87
# 2023-11-19 00:02:44+00:00              0.779444          28                85
# ...                                         ...         ...               ...
# 2023-12-18 23:55:12+00:00              0.323278          28                85
# 2023-12-18 23:56:11+00:00              0.336389          28                85
# 2023-12-18 23:57:11+00:00              0.349722          28                85
# 2023-12-18 23:58:11+00:00              0.363056          28                85
# 2023-12-18 23:59:11+00:00              0.376389          28                85
#
#                                             created_at deleted_at sensor_name
# 2023-11-19 00:00:44+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT  \
# 2023-11-19 00:00:45+00:00  2023-09-29T18:46:25.000000Z       None  WIND02_EXT
# 2023-11-19 00:01:44+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# 2023-11-19 00:01:45+00:00  2023-09-29T18:46:25.000000Z       None  WIND02_EXT
# 2023-11-19 00:02:44+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# ...                                                ...        ...         ...
# 2023-12-18 23:55:12+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# 2023-12-18 23:56:11+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# 2023-12-18 23:57:11+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# 2023-12-18 23:58:11+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
# 2023-12-18 23:59:11+00:00  2023-09-29T18:46:25.000000Z       None  WIND01_EXT
#
#                           channel_name  sensor_type  ...  serial_number
# 2023-11-19 00:00:44+00:00   wind_speed          242  ...      R23031202  \
# 2023-11-19 00:00:45+00:00   wind_speed          242  ...      R23031310
# 2023-11-19 00:01:44+00:00   wind_speed          242  ...      R23031202
# 2023-11-19 00:01:45+00:00   wind_speed          242  ...      R23031310
# 2023-11-19 00:02:44+00:00   wind_speed          242  ...      R23031202
# ...                                ...          ...  ...            ...
# 2023-12-18 23:55:12+00:00   wind_speed          242  ...      R23031202
# 2023-12-18 23:56:11+00:00   wind_speed          242  ...      R23031202
# 2023-12-18 23:57:11+00:00   wind_speed          242  ...      R23031202
# 2023-12-18 23:58:11+00:00   wind_speed          242  ...      R23031202
# 2023-12-18 23:59:11+00:00   wind_speed          242  ...      R23031202
#
#                           configuration_json address dx dy  dz  nx  ny
# 2023-11-19 00:00:44+00:00                 []      71  0  0   0   1   1  \
# 2023-11-19 00:00:45+00:00                 []      86  0  0   0   1   1
# 2023-11-19 00:01:44+00:00                 []      71  0  0   0   1   1
# 2023-11-19 00:01:45+00:00                 []      86  0  0   0   1   1
# 2023-11-19 00:02:44+00:00                 []      71  0  0   0   1   1
# ...                                      ...     ... .. ..  ..  ..  ..
# 2023-12-18 23:55:12+00:00                 []      71  0  0   0   1   1
# 2023-12-18 23:56:11+00:00                 []      71  0  0   0   1   1
# 2023-12-18 23:57:11+00:00                 []      71  0  0   0   1   1
# 2023-12-18 23:58:11+00:00                 []      71  0  0   0   1   1
# 2023-12-18 23:59:11+00:00                 []      71  0  0   0   1   1
#
#                                  zones_ids
# 2023-11-19 00:00:44+00:00  [1, 35, 36, 37]  \
# 2023-11-19 00:00:45+00:00  [1, 35, 36, 37]
# 2023-11-19 00:01:44+00:00  [1, 35, 36, 37]
# 2023-11-19 00:01:45+00:00  [1, 35, 36, 37]
# 2023-11-19 00:02:44+00:00  [1, 35, 36, 37]
# ...                                    ...
# 2023-12-18 23:55:12+00:00  [1, 35, 36, 37]
# 2023-12-18 23:56:11+00:00  [1, 35, 36, 37]
# 2023-12-18 23:57:11+00:00  [1, 35, 36, 37]
# 2023-12-18 23:58:11+00:00  [1, 35, 36, 37]
# 2023-12-18 23:59:11+00:00  [1, 35, 36, 37]
#
#                                                                  zones_names
# 2023-11-19 00:00:44+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-11-19 00:00:45+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-11-19 00:01:44+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-11-19 00:01:45+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-11-19 00:02:44+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# ...                                                                      ...
# 2023-12-18 23:55:12+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-12-18 23:56:11+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-12-18 23:57:11+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-12-18 23:58:11+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 2023-12-18 23:59:11+00:00  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
#
# [62861 rows x 23 columns]

# %%
df_log_unique_sensor["Bioschmid"]["WIND02_EXT"]
# Out:
#                            time  sensor_channel_id  Wind direction [°]
# 0     2023-11-19 00:00:00+00:00               1084                 157  \
# 5     2023-11-19 00:10:00+00:00               1084                  49
# 12    2023-11-19 00:20:00+00:00               1084                 202
# 19    2023-11-19 00:30:00+00:00               1084                 157
# 25    2023-11-19 00:40:00+00:00               1084                 133
# ...                         ...                ...                 ...
# 21013 2023-12-18 22:30:00+00:00               1084                 163
# 21015 2023-12-18 22:40:00+00:00               1084                 203
# 21016 2023-12-18 22:50:00+00:00               1084                 127
# 21018 2023-12-18 23:00:00+00:00               1084                 104
# 21020 2023-12-18 23:50:00+00:00               1084                 122
#
#        integrated [° · h]  gateway_id  local_channel_id
# 0              135.427078          28                86  \
# 5              144.810410          28                86
# 12             165.827087          28                86
# 19             194.202087          28                86
# 25             219.552078          28                86
# ...                   ...         ...               ...
# 21013         3633.378418          28                86
# 21015         3639.331055          28                86
# 21016         3669.581055          28                86
# 21018            0.388333          28                86
# 21020          100.780418          28                86
#
#                         created_at deleted_at sensor_name    channel_name
# 0      2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction  \
# 5      2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 12     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 19     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 25     2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# ...                            ...        ...         ...             ...
# 21013  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21015  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21016  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21018  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
# 21020  2023-09-29T18:46:25.000000Z       None  WIND02_EXT  wind_direction
#
#        ...  serial_number  configuration_json address dx dy dz  nx  ny
# 0      ...      R23031310                  []      86  0  0  0   1   1  \
# 5      ...      R23031310                  []      86  0  0  0   1   1
# 12     ...      R23031310                  []      86  0  0  0   1   1
# 19     ...      R23031310                  []      86  0  0  0   1   1
# 25     ...      R23031310                  []      86  0  0  0   1   1
# ...    ...            ...                 ...     ... .. .. ..  ..  ..
# 21013  ...      R23031310                  []      86  0  0  0   1   1
# 21015  ...      R23031310                  []      86  0  0  0   1   1
# 21016  ...      R23031310                  []      86  0  0  0   1   1
# 21018  ...      R23031310                  []      86  0  0  0   1   1
# 21020  ...      R23031310                  []      86  0  0  0   1   1
#
#              zones_ids                                        zones_names
# 0      [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 5      [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 12     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 19     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 25     [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# ...                ...                                                ...
# 21013  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21015  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21016  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21018  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
# 21020  [1, 35, 36, 37]  [Steuerung Zone, Agrotrack, Agroverti, Kontrol...
#
# [3793 rows x 24 columns]

# %%
old_day = 0
missing_values = 0
dict_test = {}
for index, row in dict_merged_df["Bioschmid"]["WIND02_EXT"].iterrows():
    new_day = row['time'].day
    if new_day == old_day and pd.isnull(row["value_sensor"]):
        missing_values += 1
    if new_day != old_day:
        # dict_days[datetime(year=row["time"].year, month=row["time"].month, day=row["time"].day) - timedelta(days=1)] = missing_values*10 / 1430 * 100
        dict_test[row["time"]] = missing_values
        old_day = new_day
        missing_values = 0

# %%
dict_test
# Out:
# {Timestamp('2023-11-19 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-11-20 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-11-21 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-11-22 00:00:00+0000', tz='UTC'): 8,
#  Timestamp('2023-11-23 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-11-24 00:00:00+0000', tz='UTC'): 2,
#  Timestamp('2023-11-25 00:00:00+0000', tz='UTC'): 8,
#  Timestamp('2023-11-26 00:00:00+0000', tz='UTC'): 30,
#  Timestamp('2023-11-27 00:00:00+0000', tz='UTC'): 21,
#  Timestamp('2023-11-28 00:00:00+0000', tz='UTC'): 15,
#  Timestamp('2023-11-29 00:00:00+0000', tz='UTC'): 5,
#  Timestamp('2023-11-30 00:00:00+0000', tz='UTC'): 2,
#  Timestamp('2023-12-01 00:00:00+0000', tz='UTC'): 19,
#  Timestamp('2023-12-02 00:00:00+0000', tz='UTC'): 20,
#  Timestamp('2023-12-03 00:00:00+0000', tz='UTC'): 112,
#  Timestamp('2023-12-04 00:00:00+0000', tz='UTC'): 94,
#  Timestamp('2023-12-05 00:00:00+0000', tz='UTC'): 95,
#  Timestamp('2023-12-06 00:00:00+0000', tz='UTC'): 17,
#  Timestamp('2023-12-07 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-08 00:00:00+0000', tz='UTC'): 11,
#  Timestamp('2023-12-09 00:00:00+0000', tz='UTC'): 5,
#  Timestamp('2023-12-10 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-11 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-12 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-13 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-14 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-15 00:00:00+0000', tz='UTC'): 0,
#  Timestamp('2023-12-16 00:00:00+0000', tz='UTC'): 3,
#  Timestamp('2023-12-17 00:00:00+0000', tz='UTC'): 15,
#  Timestamp('2023-12-18 00:00:00+0000', tz='UTC'): 9}

# %%
dict_df_missing_values["Etchelecu"]["WIND02_EXT"]
# Out:
#                      0
# 2023-11-18    0.000000
# 2023-11-19    0.000000
# 2023-11-20    0.000000
# 2023-11-21   41.958042
# 2023-11-22   58.741259
# 2023-11-23    5.594406
# 2023-11-24    0.000000
# 2023-11-25    2.797203
# 2023-11-26    0.000000
# 2023-11-27    0.000000
# 2023-11-28    3.496503
# 2023-11-29   40.559441
# 2023-11-30  100.000000
# 2023-12-01  100.000000
# 2023-12-02  100.000000
# 2023-12-03  100.000000
# 2023-12-04  100.000000
# 2023-12-05   33.566434
# 2023-12-06    4.195804
# 2023-12-07   19.580420
# 2023-12-08    6.993007
# 2023-12-09    0.000000
# 2023-12-10    0.000000
# 2023-12-11    8.391608
# 2023-12-12   13.986014
# 2023-12-13    0.000000
# 2023-12-14    0.000000
# 2023-12-15    0.000000
# 2023-12-16    6.293706
# 2023-12-17    0.000000
# 2023-12-18   16.083916

# %%
date_range = pd.date_range(start=df_log_unique_sensor[instal][unique_sensor]['time'].min().tz_localize(None), end=pd.to_datetime(datetime.now().strftime("%Y-%m-%d %H:%M:%S")) + pd.DateOffset(0), freq='10min')

# %%
date_range = date_range.tz_localize(pytz.timezone('UTC'))

# %%
date_range
# Out:
# DatetimeIndex(['2023-12-05 08:10:00+00:00', '2023-12-05 08:20:00+00:00',
#                '2023-12-05 08:30:00+00:00', '2023-12-05 08:40:00+00:00',
#                '2023-12-05 08:50:00+00:00', '2023-12-05 09:00:00+00:00',
#                '2023-12-05 09:10:00+00:00', '2023-12-05 09:20:00+00:00',
#                '2023-12-05 09:30:00+00:00', '2023-12-05 09:40:00+00:00',
#                ...
#                '2024-01-03 08:50:00+00:00', '2024-01-03 09:00:00+00:00',
#                '2024-01-03 09:10:00+00:00', '2024-01-03 09:20:00+00:00',
#                '2024-01-03 09:30:00+00:00', '2024-01-03 09:40:00+00:00',
#                '2024-01-03 09:50:00+00:00', '2024-01-03 10:00:00+00:00',
#                '2024-01-03 10:10:00+00:00', '2024-01-03 10:20:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=4190, freq='10T')
